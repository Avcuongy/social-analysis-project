# %% [markdown]
# 1. Load Data
# 2. Build Graph
# 3. Modularity-based Community Detection
# 4. Leiden Algorithm
# 5. Community Statistics
# 6. Community Interpretation
# 7. Community Visualization
# 8. Top Influencers per Community
# 9. Insights

# %% [markdown]
# # Lib

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

from scipy.stats import linregress

import warnings
warnings.filterwarnings("ignore")
