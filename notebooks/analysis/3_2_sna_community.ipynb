# %% [markdown]
# 1. Load Data
# 2. Build Graph
# 3. Modularity-based Community Detection
# 4. Lovain Algorithm
# 5. Leiden Algorithm
# 6. Community Statistics
# 7. Community Interpretation
# 8. Community Visualization
# 9. Top Influencers per Community
# 10. Insights

# %% [markdown]
# # Lib

# %%
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

from scipy.stats import linregress

import warnings
warnings.filterwarnings("ignore")
