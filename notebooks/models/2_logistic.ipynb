# %% [markdown]
# # Lib

# %% [markdown]
# # Data preparation

# %%
# train 80, test 20
# feature extraction + original features -> graph embedding -> 
# 2 file embedding:
#     - deepwalk
#     - node2vec

# %% [markdown]
# # Func

# %% [markdown]
# # Model

# %% [markdown]
# # Train

# %% [markdown]
# # Evaluation

# %% [markdown]
# # Predict

# %% [markdown]
# # I/O

# %%
load lại model -> evalate lại trên test coi giống không
